# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
class Electron():
    def __init__(self, xx, yy, zz, en, ID):
        self.x, self.y, self.z = xx, yy, zz
        self.energy = en
        self.id = ID
fin = open("particles-tracks", "r")
prim = Electron(0, 0, 0, 0, 1)
track = 0
depth = 0
penetration = False
part = ''
ID = 1
extruders = set()
cercount = 0
run = 1

result = []

x, y, z, en1, xx, yy, zz, en = 0, 0, 0, 0, 0, 0, 0, 0
for string in fin.readlines()[1:]:
    #print(string[:-1].split("\t"))
    if string == "\n" or "":
        depth = ((prim.x - x) ** 2 + (prim.y - y) ** 2 + (prim.z - z) ** 2) ** 0.5
        result.append((run, depth, track, len(extruders)))
        #print("Run", run)
        run += 1
        #print('Length of path is', track)
        track = 0

        #print("Depth is ", depth)
        #print(len(extruders), "Cerenkov photons passed through border\n")
        #print(extruders)
        extruders = set()
        penetration = False
    else:   
        try:
            part, x, y, z, en1, xx, yy, zz, en, ID = string[:-1].split("\t")
        except:
            pass
            #print(string)
        x, y, z, en1, xx, yy, zz, en = map(float, (x, y, z, en1, xx, yy, zz, en))
        ID = int(ID)
        if ID == 1:
            if penetration:
                track += ((xx - x) ** 2 + (yy - y) ** 2 + (zz - z) ** 2)**0.5
            elif zz == -20.0:
                prim.x, prim.y, prim.z = xx, yy, zz #beginning of penetration
                penetration = True
            prim.energy = en
            #print(x, y, z, en1, xx, yy, zz, en, track, sep ="\t")
            #if prim.energy == 0 and en1 == 0:   
        elif part == "opticalphoton" and zz == 40.0 and (xx * 2 + yy **2 <= 1) and ID not in extruders:
            #print("ID", ID, "photon passed through border")
            extruders.add(ID)
else:
    depth = ((prim.x - x) ** 2 + (prim.y - y) ** 2 + (prim.z - z) ** 2) ** 0.5
    result.append((run, depth, track, len(extruders)))
    #print("Run", run)
    run += 1
    #print('Length of path is', track)
    track = 0
    #print("Depth is ", depth)
    #print(len(extruders), "Cerenkov photons passed through border\n")
    #print(extruders)
    extruders = set()
    penetration = False
fin.close()
df = pd.DataFrame(result)
df.index = df[0]
edf = pd.read_csv("logoutput", sep = "\t")
edf.index = edf['Run']
df['Edep'] = edf['Edep']
df['CerCount'] = edf['CerCount']
df.columns = ['Run', 'Distance', 'Length', 'Counts', 'Edep', 'CerCount']
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib64/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Edep'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1-e2074cdef1a2> in <module>
#      73 edf = pd.read_csv("logoutput", sep = "\t")
#      74 edf.index = edf['Run']
# ---> 75 df['Edep'] = edf['Edep']
#      76 df['CerCount'] = edf['CerCount']
#      77 df.columns = ['Run', 'Distance', 'Length', 'Counts', 'Edep', 'CerCount']
#
# /usr/local/lib64/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# /usr/local/lib64/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Edep'

# %%
df.to_csv("15MeVData.csv")

# %%
df1 = pd.read_csv("05MeVData.csv")
df2 = pd.read_csv("15MeVData.csv")

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.set_title(label="Плотность распределения длин пройденного электроном пути")

ax.set_xlim(left=0.0, right=200)
#ax.set_ylim(bottom = 0.00001, top = 0.1)
#ax.set_yscale('log')
#ax.set_xscale('log')
#ax.set_ylim(bottom=0, top = 0.15)
ax.set_xlabel('Длина пути, мм')
ax.set_ylabel('Количество запусков')
ax.grid(True)
ax.tick_params(direction = 'in')
fig.tight_layout()
df1['Length'].plot.kde(ax = ax)
df2['Length'].plot.kde(ax = ax)
#plt.plot(df1['Length'], label = '0.5 МэВ')
#plt.plot(df2['Length'], label = '1.5 М	2.511663e+00	29
ax.legend()
plt.savefig("distance.png")

# %%
df = pd.read_csv("logoutput1", sep='   ', engine='python')
df.describe()
# Out:
#                  Run          Eprim          Teta        edepSi1  \
# count  100000.000000  100000.000000  1.000000e+05  100000.000000
# mean    50000.500000       6.507630  4.651547e-02       0.014004
# std     28867.657797       3.181588  2.695719e-02       0.019530
# min         1.000000       1.000133  5.358027e-07       0.002531
# 25%     25000.750000       3.745742  2.305867e-02       0.008821
# 50%     50000.500000       6.531622  4.651952e-02       0.010786
# 75%     75000.250000       9.275342  6.986036e-02       0.013621
# max    100000.000000      11.999970  9.328886e-02       0.619474
#
#              edepSi2        edepSiC        edepSi3        edepSum  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean        0.194980       5.984010       0.000246       6.193240
# std         0.121873       3.089575       0.010580       3.067110
# min         0.000000       0.000000       0.000000       0.006123
# 25%         0.141749       3.381755       0.000000       3.582663
# 50%         0.158374       5.981793       0.000000       6.178254
# 75%         0.192153       8.567743       0.000000       8.757442
# max         3.236232      11.874060       1.352972      12.007290
#
#             CerCount
# count  100000.000000
# mean     1508.512010
# std       846.039506
# min         0.000000
# 25%       789.000000
# 50%      1498.000000
# 75%      2207.000000
# max      3570.000000

# %%
fig, ax = plt.subplots(figsize=(7,7))
#ax.set_title(label="Плотность распределения длин пройденного электроном пути")

#ax.set_xlim(left=0.0, right=3.0)
#ax.set_ylim(bottom = 0., top = 12.0)
#ax.set_yscale('log')
#ax.set_xscale('log')
#ax.set_ylim(bottom=0, top = 0.15)
ax.set_xlabel('Выделение в первом детекторе, МэВ', fontsize=15)
ax.set_ylabel('Выделение во втором детекторе, МэВ', fontsize=15)
ax.grid(True)
ax.tick_params(direction = 'in')
fig.tight_layout()
df1 = df[(df['Eprim'] <= 3.5) & (df['Eprim'] >= 1)]
df2 = df[(df['Eprim'] >= 3.5) & (df['Eprim'] <= 6)]
df3 = df[(df['Eprim'] >= 6) & (df['Eprim'] <= 8.5)]
df4 = df[(df['Eprim'] >= 8.5) & (df['Eprim'] <= 11)]
#plt.scatter(df1['edepSi1'], df1['edepSi2'], s=1,c='r', label = '1$-$3.5 МэВ')
#plt.scatter(df2['edepSi1'], df2['edepSi2'], s=1,c='b', label = '3.5$-$6 МэВ')
#plt.scatter(df3['edepSi1'], df3['edepSi2'], s=1,c='g', label = '6$-$8.5 МэВ')
#plt.scatter(df4['edepSi1'], df4['edepSi2'], s=1,c='m', label = '8.5$-$11 МэВ')


ax.legend(fontsize=15)
#plt.savefig("Result/Si12CorrPlot.png")
# Out:
# No handles with labels found to put in legend.

# %%
fig, ax = plt.subplots(figsize=(7,7))
ax.set_xlim(right = 0.1)
sns_plot = sns.distplot(df1['edepSi1'],  color = 'r', label = '1$-$3.5 МэВ', ax = ax, kde = False, bins = 400)
sns.distplot(df2['edepSi1'],  color = 'b', label = '3.5$-$6 МэВ', ax = ax, kde = False, bins = 400)
sns.distplot(df3['edepSi1'],  color = 'g', label = '6$-$8.5 МэВ', ax = ax, kde = False, bins = 400)
sns.distplot(df4['edepSi1'],  color = 'm', label = '8.5$-$11 МэВ', ax= ax, kde = False, bins = 400)
ax.set_xlabel('Энерговыделение в первом детекторе, МэВ', fontsize=15)
ax.set_ylabel('Число событий', fontsize=15)
ax.legend(fontsize=15)
plt.savefig("Result/EdepSi1Hist.png")

# %%
df4[df4['edepSi3'] > 0].describe()
# Out:
#                 Run      Eprim       Teta    edepSi1    edepSi2    edepSiC  \
# count     63.000000  63.000000  63.000000  63.000000  63.000000  63.000000
# mean   45647.634921   9.798377   0.041632   0.013905   0.159176   7.572695
# std    28292.206870   0.696075   0.027104   0.013985   0.033852   1.880399
# min      136.000000   8.514913   0.000241   0.005635   0.124198   2.293895
# 25%    18775.500000   9.318138   0.014642   0.008847   0.139491   6.756072
# 50%    47417.000000   9.817748   0.038933   0.010517   0.148973   8.224874
# 75%    68501.000000  10.428205   0.067912   0.012895   0.164432   8.871310
# max    96297.000000  10.925380   0.088411   0.087154   0.304748  10.520660
#
#          edepSi3    edepSum     CerCount
# count  63.000000  63.000000    63.000000
# mean    0.198752   7.944528  1916.698413
# std     0.251056   1.817256   531.105986
# min     0.000577   3.051617   456.000000
# 25%     0.044783   7.119557  1682.500000
# 50%     0.137408   8.396783  2008.000000
# 75%     0.228175   9.341601  2321.500000
# max     1.352972  10.736510  2887.000000
